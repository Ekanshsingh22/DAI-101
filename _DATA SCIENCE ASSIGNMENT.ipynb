# %%
import pandas as pd
import numpy as np
data=pd.read_csv("diabetes_dataset.csv")

# %%
data
# Out:
#       Age  Pregnancies    BMI  Glucose  BloodPressure  HbA1c    LDL   HDL  \
# 0      69            5  28.39    130.1           77.0    5.4  130.4  44.0
# 1      32            1  26.49    116.5           72.0    4.5   87.4  54.2
# 2      89           13  25.34    101.0           82.0    4.9  112.5  56.8
# 3      78           13  29.91    146.0          104.0    5.7   50.7  39.1
# 4      38            8  24.56    103.2           74.0    4.7  102.5  29.1
# ...   ...          ...    ...      ...            ...    ...    ...   ...
# 9533   32            3  23.00    102.3           62.0    4.1  109.3  47.8
# 9534   74            0  24.29    125.8           93.0    5.3   95.8  66.6
# 9535   75            6  26.10    107.6           75.0    5.0  168.5  62.3
# 9536   52            1  25.88     99.3           96.0    4.6   70.0  48.4
# 9537   33            3  25.61     69.1           65.0    4.0   69.0  59.4
#
#       Triglycerides  WaistCircumference  HipCircumference   WHR  \
# ...

# %%
data.head()
# Out:
#    Age  Pregnancies    BMI  Glucose  BloodPressure  HbA1c    LDL   HDL  \
# 0   69            5  28.39    130.1           77.0    5.4  130.4  44.0
# 1   32            1  26.49    116.5           72.0    4.5   87.4  54.2
# 2   89           13  25.34    101.0           82.0    4.9  112.5  56.8
# 3   78           13  29.91    146.0          104.0    5.7   50.7  39.1
# 4   38            8  24.56    103.2           74.0    4.7  102.5  29.1
#
#    Triglycerides  WaistCircumference  HipCircumference   WHR  FamilyHistory  \
# 0           50.0                90.5             107.9  0.84              0
# 1          129.9               113.3              81.4  1.39              0
# 2          177.6                84.7             107.2  0.79              0
# 3          117.0               108.9             110.0  0.99              0
# 4          145.9                84.1              92.8  0.91              0
#
#    DietType  Hypertension  MedicationUse  Outcome
# ...

# %%
cat = []
num = []

for column in data.columns:  
    if data[column].nunique() < 10:  
        cat.append(column)  
    else:
        num.append(column)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
cat
# Out:
# ['FamilyHistory', 'DietType', 'Hypertension', 'MedicationUse', 'Outcome']

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9538 entries, 0 to 9537
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Age                 9538 non-null   int64
#  1   Pregnancies         9538 non-null   int64
#  2   BMI                 9538 non-null   float64
#  3   Glucose             9538 non-null   float64
#  4   BloodPressure       9538 non-null   float64
#  5   HbA1c               9538 non-null   float64
#  6   LDL                 9538 non-null   float64
#  7   HDL                 9538 non-null   float64
#  8   Triglycerides       9538 non-null   float64
#  9   WaistCircumference  9538 non-null   float64
#  10  HipCircumference    9538 non-null   float64
#  11  WHR                 9538 non-null   float64
#  12  FamilyHistory       9538 non-null   int64
#  13  DietType            9538 non-null   int64
#  14  Hypertension        9538 non-null   int64
# ...

# %%
data.describe()
# Out:
#                Age  Pregnancies          BMI      Glucose  BloodPressure  \
# count  9538.000000  9538.000000  9538.000000  9538.000000    9538.000000
# mean     53.577584     7.986161    27.052364   106.104183      84.475781
# std      20.764651     4.933469     5.927955    21.918590      14.123480
# min      18.000000     0.000000    15.000000    50.000000      60.000000
# 25%      36.000000     4.000000    22.870000    91.000000      74.000000
# 50%      53.000000     8.000000    27.050000   106.000000      84.000000
# 75%      72.000000    12.000000    31.180000   121.000000      94.000000
# max      89.000000    16.000000    49.660000   207.200000     138.000000
#
#              HbA1c          LDL          HDL  Triglycerides  \
# count  9538.000000  9538.000000  9538.000000    9538.000000
# mean      4.650661   100.133456    49.953418     151.147746
# std       0.476395    29.911910    15.242194      48.951627
# min       4.000000   -12.000000    -9.200000      50.000000
# ...

# %%
data.isnull().sum()
# Out:
# Age                   0
# Pregnancies           0
# BMI                   0
# Glucose               0
# BloodPressure         0
# HbA1c                 0
# LDL                   0
# HDL                   0
# Triglycerides         0
# WaistCircumference    0
# HipCircumference      0
# WHR                   0
# FamilyHistory         0
# DietType              0
# Hypertension          0
# MedicationUse         0
# Outcome               0
# dtype: int64

# %%
data.drop_duplicates(inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9538 entries, 0 to 9537
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Age                 9538 non-null   int64
#  1   Pregnancies         9538 non-null   int64
#  2   BMI                 9538 non-null   float64
#  3   Glucose             9538 non-null   float64
#  4   BloodPressure       9538 non-null   float64
#  5   HbA1c               9538 non-null   float64
#  6   LDL                 9538 non-null   float64
#  7   HDL                 9538 non-null   float64
#  8   Triglycerides       9538 non-null   float64
#  9   WaistCircumference  9538 non-null   float64
#  10  HipCircumference    9538 non-null   float64
#  11  WHR                 9538 non-null   float64
#  12  FamilyHistory       9538 non-null   int64
#  13  DietType            9538 non-null   int64
#  14  Hypertension        9538 non-null   int64
# ...

# %%
data
# Out:
#       Age  Pregnancies    BMI  Glucose  BloodPressure  HbA1c    LDL   HDL  \
# 0      69            5  28.39    130.1           77.0    5.4  130.4  44.0
# 1      32            1  26.49    116.5           72.0    4.5   87.4  54.2
# 2      89           13  25.34    101.0           82.0    4.9  112.5  56.8
# 3      78           13  29.91    146.0          104.0    5.7   50.7  39.1
# 4      38            8  24.56    103.2           74.0    4.7  102.5  29.1
# ...   ...          ...    ...      ...            ...    ...    ...   ...
# 9533   32            3  23.00    102.3           62.0    4.1  109.3  47.8
# 9534   74            0  24.29    125.8           93.0    5.3   95.8  66.6
# 9535   75            6  26.10    107.6           75.0    5.0  168.5  62.3
# 9536   52            1  25.88     99.3           96.0    4.6   70.0  48.4
# 9537   33            3  25.61     69.1           65.0    4.0   69.0  59.4
#
#       Triglycerides  WaistCircumference  HipCircumference   WHR  \
# ...

# %% [markdown]
# ## univariate analysis

# %% [markdown]
# ## categorical

# %%
data['FamilyHistory'].value_counts().plot(kind='pie',autopct="%1.2f%%")
plt.title("Family history")
# Out:
# Text(0.5, 1.0, 'Family history')

# %%
data['FamilyHistory'].value_counts()
# Out:
# 0    6653
# 1    2885
# Name: FamilyHistory, dtype: int64

# %%
data['FamilyHistory'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
data['DietType'].value_counts()
# Out:
# 0    5794
# 1    2851
# 2     893
# Name: DietType, dtype: int64

# %%
data['DietType'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
data['MedicationUse'].value_counts()
# Out:
# 0    5675
# 1    3863
# Name: MedicationUse, dtype: int64

# %%
data['MedicationUse'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
data['Outcome'].value_counts().plot(kind='pie',autopct="%1.2f%%")
plt.title("patient have diabetes or not")
# Out:
# Text(0.5, 1.0, 'patient have diabetes or not')

# %% [markdown]
# # univariate analysis for numerical

# %%
num
# Out:
# ['Age',
#  'Pregnancies',
#  'BMI',
#  'Glucose',
#  'BloodPressure',
#  'HbA1c',
#  'LDL',
#  'HDL',
#  'Triglycerides',
#  'WaistCircumference',
#  'HipCircumference',
#  'WHR']

# %%
sns.distplot(data['Age'])
plt.title("Age of patient")
# Out:
# C:\Users\vanda\AppData\Local\Temp\ipykernel_14128\2706658041.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Age'])
# Text(0.5, 1.0, 'Age of patient')

# %%
sns.distplot(data['Pregnancies'])
plt.title("Pregnancies of patient")
# Out:
# C:\Users\vanda\AppData\Local\Temp\ipykernel_14128\2464368475.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Pregnancies'])
# Text(0.5, 1.0, 'Pregnancies of patient')

# %%
data['Pregnancies'].skew()
# Out:
# 0.015816989454971765

# %%
sns.distplot(data['WaistCircumference'])
plt.title("WaistCircumference of patients")
# Out:
# C:\Users\vanda\AppData\Local\Temp\ipykernel_14128\976692648.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['WaistCircumference'])
# Text(0.5, 1.0, 'WaistCircumference of patients')

# %%
sns.distplot(data['Glucose'])
plt.title("Glucose of patient")
# Out:
# C:\Users\vanda\AppData\Local\Temp\ipykernel_14128\142191948.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Glucose'])
# Text(0.5, 1.0, 'Glucose of patient')

# %%
data['Glucose'].skew()
# Out:
# 0.061714729533192736

# %%
sns.boxplot(data['Glucose'])
# Out:
# <Axes: >

# %%
sns.boxplot(data['BloodPressure'])
# Out:
# <Axes: >

# %%
num_cols = ['Age', 'Pregnancies', 'BMI', 'Glucose', 'BloodPressure', 'HbA1c', 'LDL', 'HDL', 'Triglycerides', 'WaistCircumference', 'HipCircumference', 'WHR']
data[num_cols].hist(figsize=(12, 10), bins=20)
plt.suptitle("Distributions")
plt.show()

# %%
plt.figure(figsize=(15, 6))
sns.boxplot(data=data[num_cols])
plt.xticks(rotation=45)
plt.title("Boxplot of Numerical Features")
plt.show()

# %% [markdown]
# # bivariate analysis

# %% [markdown]
# # numerical numerical

# %%
num
# Out:
# ['Age',
#  'Pregnancies',
#  'BMI',
#  'Glucose',
#  'BloodPressure',
#  'HbA1c',
#  'LDL',
#  'HDL',
#  'Triglycerides',
#  'WaistCircumference',
#  'HipCircumference',
#  'WHR']

# %%
sns.scatterplot(data=data,x="Age",y="Glucose")
plt.title("glucose level with age")
# Out:
# Text(0.5, 1.0, 'glucose level with age')

# %% [markdown]
# # we can see that glucose level increasing with age

# %%
sns.scatterplot(data=data,x="Age",y="BMI")
plt.title("Bmi with age")
# Out:
# Text(0.5, 1.0, 'Bmi with age')

# %% [markdown]
# # there is no such directly proportion  relation of bmi with age

# %%
sns.scatterplot(data=data,x="Age",y="LDL")
plt.title("ldl with age")
# Out:
# Text(0.5, 1.0, 'ldl with age')

# %%
sns.scatterplot(data=data,x="WaistCircumference",y="HipCircumference")
plt.title("waistcircumference vs hipcircumference")
# Out:
# Text(0.5, 1.0, 'waistcircumference vs hipcircumference')

# %% [markdown]
# # there is direct proportionality between them

# %% [markdown]
# # between categorical and numerical

# %%
cat
# Out:
# ['FamilyHistory', 'DietType', 'Hypertension', 'MedicationUse', 'Outcome']

# %%
num
# Out:
# ['Age',
#  'Pregnancies',
#  'BMI',
#  'Glucose',
#  'BloodPressure',
#  'HbA1c',
#  'LDL',
#  'HDL',
#  'Triglycerides',
#  'WaistCircumference',
#  'HipCircumference',
#  'WHR']

# %%
sns.barplot(data=data,y="BloodPressure",x="Outcome")
# Out:
# <Axes: xlabel='Outcome', ylabel='BloodPressure'>

# %% [markdown]
# # every level of bloodpressure have diabetes or not

# %%
sns.barplot(data=data,y="Glucose",x="Outcome")
# Out:
# <Axes: xlabel='Outcome', ylabel='Glucose'>

# %% [markdown]
# # same for glucose as blood pressure with diabetes

# %%
sns.barplot(data=data,y="Glucose",x="FamilyHistory")
# Out:
# <Axes: xlabel='FamilyHistory', ylabel='Glucose'>

# %%
sns.barplot(data=data,y="BloodPressure",x="DietType")
# Out:
# <Axes: xlabel='DietType', ylabel='BloodPressure'>

# %%
sns.barplot(data=data,y="Pregnancies",x="Outcome")
# Out:
# <Axes: xlabel='Outcome', ylabel='Pregnancies'>

# %% [markdown]
# # categorical - categorical

# %%
cat
# Out:
# ['FamilyHistory', 'DietType', 'Hypertension', 'MedicationUse', 'Outcome']

# %%
pd.crosstab(data['FamilyHistory'],data['Outcome'])
# Out:
# Outcome           0     1
# FamilyHistory
# 0              6256   397
# 1                 0  2885

# %% [markdown]
# # if fame history have diabetes then there are chances that patient have also

# %%
pd.crosstab(data['DietType'],data['Outcome'])
# Out:
# Outcome      0     1
# DietType
# 0         3766  2028
# 1         1892   959
# 2          598   295

# %%
pd.crosstab(data['MedicationUse'],data['Outcome'])
# Out:
# Outcome           0     1
# MedicationUse
# 0              3866  1809
# 1              2390  1473

# %% [markdown]
# # not tell confidentally

# %%
pd.crosstab(data['Hypertension'],data['Outcome'])
# Out:
# Outcome          0     1
# Hypertension
# 0             6254  3274
# 1                2     8

# %% [markdown]
# # CORRELATION MATRIX

# %%
corr_vars = [col for col in data.columns]
corr_matrix = data[corr_vars].corr()

plt.figure(figsize=(12, 10))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix')
plt.show()
